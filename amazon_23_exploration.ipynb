# %% [markdown]
# # playground notebook for exploring the Amazon review dataset.
# I chose the [Amazon review dataset](https://cseweb.ucsd.edu/~jmcauley/datasets.html#amazon_reviews) from UCSD. For the purpose of building POC I chose only one category of items (all beauty products). The dataset
# contains both reviews (user id for the peson who gave the review, when the review was given, ...) as well as meta data related to the items (images,videos, details,...).
# In this notebook I try to become familiar with the strucure of the datasets.

# %%
import pandas as pd
import numpy as np

# %%
df_reviews = pd.read_csv('data/all_beauty_review_amazon.csv')
df_meta = pd.read_csv('data/all_beauty_meta_amazon.csv')

# %%
import pandas as pd

# Set the maximum number of rows to display
pd.set_option('display.max_rows', 50)

# %%
df_reviews.head(5)
# Out:
#    Unnamed: 0  rating                                      title  \
# 0           0     5.0  Such a lovely scent but not overpowering.
# 1           1     4.0     Works great but smells a little weird.
# 2           2     5.0                                       Yes!
# 3           3     1.0                          Synthetic feeling
# 4           4     5.0                                         A+
#
#                                                 text images        asin  \
# 0  This spray is really nice. It smells really go...     []  B00YQ6X8EO
# 1  This product does what I need it to do, I just...     []  B081TJ8YS3
# 2                          Smells good, feels great!     []  B07PNNCSP9
# 3                                     Felt synthetic     []  B09JS339BZ
# 4                                            Love it     []  B08BZ63GMJ
#
#   parent_asin                       user_id      timestamp  helpful_vote  \
# ...

# %%
df_meta.head(5)
# Out:
#    Unnamed: 0 main_category  \
# 0           0    All Beauty
# 1           1    All Beauty
# 2           2    All Beauty
# 3           3    All Beauty
# 4           4    All Beauty
#
#                                                title  average_rating  \
# 0  Howard LC0008 Leather Conditioner, 8-Ounce (4-...             4.8
# 1  Yes to Tomatoes Detoxifying Charcoal Cleanser ...             4.5
# 2   Eye Patch Black Adult with Tie Band (6 Per Pack)             4.4
# 3  Tattoo Eyebrow Stickers, Waterproof Eyebrow, 4...             3.1
# 4  Precision Plunger Bars for Cartridge Grips – 9...             4.3
#
#    rating_number                                           features  \
# 0             10                                                 []
# 1              3                                                 []
# 2             26                                                 []
# 3            102                                                 []
# ...

# %%
df_meta[df_meta['parent_asin']=='B088FKY3VD']
# Out:
#    Unnamed: 0 main_category  \
# 3           3    All Beauty
#
#                                                title  average_rating  \
# 3  Tattoo Eyebrow Stickers, Waterproof Eyebrow, 4...             3.1
#
#    rating_number features description  price  \
# 3            102       []          []    NaN
#
#                                               images  \
# 3  {'hi_res': ['https://m.media-amazon.com/images...
#
#                                     videos     store categories  \
# 3  {'title': [], 'url': [], 'user_id': []}  Cherioll         []
#
#                                              details parent_asin  \
# 3  {"Brand": "Cherioll", "Item Form": "Powder", "...  B088FKY3VD
#
#    bought_together  subtitle  author
# 3              NaN       NaN     NaN

# %%
print(df_meta['title'][df_meta['parent_asin']=='B088FKY3VD'].values)
# Out:
# ['Tattoo Eyebrow Stickers, Waterproof Eyebrow, 4D Imitation Eyebrow Tattoos, 4D Hair-like Authentic Eyebrows Waterproof Long Lasting for Woman & Man Makeup Tool']

# %%
df_reviews['text'][df_reviews['parent_asin']=='B088FKY3VD'].values
# Out:
# array(['Poor quality',
#        'Hard to get them on matching. After applying it leaves a shiny area above the brow.',
#        'Easy to use - Look natural.  It would be best if the products pre-cut ready to use.  Strongly recommend.',
#        "I love these eyebrow tattoos.  The only thing I would change is the availability to order a box of the same style instead of a variety.  For me I have to change daily.  I might be able to go two days, but rarely.  Also I think the oil they give to remove should be a bigger bottle.  I use that up quickly and end up using baby oil, which doesn't work as well.",
#        'Save your money,  If you can get then to go on they don’t stay on.  I’ll save them for halloween',
#        'Don’t waste your money on this product. It’s basically a clear sticker that you put on top of your skin. It’s doesn’t look natural at all!',
# ...
